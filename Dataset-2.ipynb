# %%
import os
from pathlib import Path
import pandas as pd

# %%
import os

p = r"D:\Compressed\lavikinnean-data"

# Get only subfolders
subfolders = [e.name for e in os.scandir(p) if e.is_dir()]

print("Subfolders:")
for folder in sorted(subfolders):
    print(f"{folder}")

print(f"\nTotal subfolders: {len(subfolders)}")
# Out:
# Subfolders:
#
# Total subfolders: 0
